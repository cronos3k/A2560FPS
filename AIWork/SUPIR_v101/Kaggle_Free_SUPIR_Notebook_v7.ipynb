# %% [markdown]
# 1.  **Free Kaggle Notebook V7 - 11 September 2025**
# 1.  **Please read instructions carefully**
# 1. **Select Accelerator GPU T4 x2 and set Internet On**
# 1. **Most updated version with config of this notebook will be on >** **https://www.patreon.com/posts/99176057**
# 1. **Tutorial: https://youtu.be/OYxVEvDf284**

# %% [markdown]
# # Install Everything - 1 Time Run

# %%
# !yes | apt-get update --allow-releaseinfo-change
# !yes | apt install libgoogle-perftools-dev
# !mkdir -p /kaggle/temp
# %cd /kaggle/temp
# !git clone https://github.com/FurkanGozukara/SUPIR 
# %cd /kaggle/temp/SUPIR
# %env PYTHONWARNINGS=ignore
# %env PYTORCH_CUDA_ALLOC_CONF=garbage_collection_threshold:0.9,max_split_size_mb:256
# %cd /kaggle/temp/SUPIR
# !pip install gradio==4.19.0
# !pip install gradio_imageslider
# !pip install gradio_client
# !pip install ffmpeg_progress_yield
# !pip install filetype==1.2.0
# !pip install k_diffusion
# !pip install Markdown==3.5.2
# !pip install numpy==1.26.4
# !pip install requests==2.31.0
# !pip install sentencepiece==0.2.0
# !pip install tokenizers # Leave this to be set by the installed transformers version
# !pip install uvicorn==0.28.0
# !pip install wandb==0.16.4
# !pip install httpx
# !pip install transformers==4.38.2
# !pip install accelerate==0.27.2
# !pip install scikit-learn==1.4.1.post1
# !pip install sentencepiece
# !pip install einops==0.7.0
# !pip install einops-exts==0.0.4
# !pip install timm==0.9.16
# !pip install openai-clip==1.0.1
# !pip install fsspec
# !pip install kornia==0.7.1
# !pip install matplotlib==3.8.3
# !pip install ninja==1.11.1.1
# !pip install omegaconf==2.3.0
# !pip install open-clip-torch==2.24.0
# !pip install opencv-python==4.9.0.80
# !pip install pandas==2.2.1
# !pip install Pillow==10.2.0
# !pip install pytorch-lightning # Leave this to be set by the installed torch version
# !pip install PyYAML==6.0.1
# !pip install scipy==1.12.0
# !pip install tqdm==4.66.2
# !pip install urllib3==2.2.1
# !pip install webdataset==0.2.86
# !pip install fastapi==0.111.0
# !pip install diffusers==0.30.0
# !pip install facexlib==0.3.0
# !pip install huggingface_hub
# !pip install bitsandbytes==0.43.0 --upgrade
# !pip install flask
# !pip install pyngrok
# !pip install pillow-avif-plugin
# !yes | apt-get install ffmpeg
# !pip install --upgrade setuptools
# !pip install huggingface_hub ipywidgets hf_transfer
# !pip install torch==2.1.0+cu121 torchvision --index-url https://download.pytorch.org/whl/cu121
# !pip install xformers==0.0.22.post7 --index-url https://download.pytorch.org/whl/cu121

# %% [markdown]
# #  Download all models

# %%
 # analyze below wget commands to download different models as you wish
# !apt-get install aria2
# !mkdir -p /kaggle/temp/SUPIR/models
# !rm -r /kaggle/temp/SUPIR/models/checkpoints
# !mkdir -p /kaggle/temp/SUPIR/models/checkpoints
# %cd /kaggle/temp/SUPIR/models/checkpoints
#decide to use whether lightning version or full version - kaggle space is limited
# !aria2c -x 16 "https://huggingface.co/MonsterMMORPG/SECourses_SUPIR/resolve/main/checkpoints/RealVisXL_V5.0_fp16.safetensors" -o "RealVisXL_V5.0_fp16.safetensors" 
#!aria2c -x 16 "https://huggingface.co/MonsterMMORPG/SECourses_SUPIR/resolve/main/checkpoints/WildCardX_XL_Lightning.safetensors" -o "WildCardX_XL_Lightning.safetensors" 
# %cd /kaggle/temp/SUPIR
# !export HF_HUB_ENABLE_HF_TRANSFER=1 
# !python download_model_kaggle.py

# %% [markdown]
# # Start the Application

# %%
# This is the cell to run the application
# Run this cell after running above cells and you will get a Gradio live share link
# Now it works with Gradio live share no needed ngrok anymore
# %cd /kaggle/temp/SUPIR
#use this for FP16
#!python gradio_demo.py --use_tile_vae --loading_half_params --load_4bit_llava --dont_move_cpu --fast_load_sd
#use this for FP8
# !export HF_HUB_ENABLE_HF_TRANSFER=1
# !python gradio_demo.py --fp8 --use_tile_vae --load_4bit_llava --dont_move_cpu --fast_load_sd --share True

# %% [markdown]
# # To download all generated Images - Cancel running app to run this cell

# %%
#run this cell to generate a zip file of all generated images and then you can download
#them from the right panel as zip file
# Navigate to the parent directory of the outputs folder
# !cd /kaggle/temp/SUPIR/

# Remove existing zip file if it exists
# !rm -f ../images.zip

# Create a new zip file with only the outputs folder
# !zip -r ../images.zip outputs

# Navigate back to the original working directory if needed
# %cd /kaggle/temp/SUPIR

# %% [markdown]
# # NOT NEEDED ANYMORE SINCE GRADIO LIVE SHARE WORKING
# ### First you need to register and get a token.
# ### I used gmail register >
# ### https://dashboard.ngrok.com/get-started/your-authtoken
# ### Skipped authenticator not necessary
# ### Here A Video Of How To Use NGROK : https://youtu.be/iBT6rhH0Fjs

# %%
### Here A Video Of How To Use NGROK : https://youtu.be/iBT6rhH0Fjs
## first put your ngrok token to the below and then run this code
## it will give a link like this at below : https://2fc5-34-134-226-xxx.ngrok-free.app
## open it and then run web ui and once web ui started that link will start working
import os
import threading

from flask import Flask
from pyngrok import ngrok, conf

conf.get_default().auth_token = "replace_with_your_ngrok_token"

os.environ["FLASK_ENV"] = "development"

app = Flask(__name__)

public_url = ngrok.connect(7860).public_url
print(" * ngrok tunnel \"{}\" -> \"http://127.0.0.1:{}/\"".format(public_url, 7860))

app.config["BASE_URL"] = public_url

@app.route("/")
def index():
    return "how to use Ngrok video : https://youtu.be/iBT6rhH0Fjs"

threading.Thread(target=app.run, kwargs={"use_reloader": False}).start()

# %%
# !du -h --max-depth=1 /usr/lib

# %%
# !pip freeze
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# absl-py==1.4.0
# accelerate==0.27.2
# aiofiles==22.1.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.12.13
# aiosignal==1.3.2
# aiosqlite==0.21.0
# alabaster==1.0.0
# albucore==0.0.24
# albumentations==2.0.8
# ale-py==0.11.1
# alembic==1.16.2
# altair==5.5.0
# annotated-types==0.7.0
# annoy==1.17.3
# ansicolors==1.1.8
# antlr4-python3-runtime==4.9.3
# anyio==4.9.0
# appdirs==1.4.4
# argon2-cffi==25.1.0
# argon2-cffi-bindings==21.2.0
# args==0.1.0
# array_record==0.7.2
# arrow==1.3.0
# arviz==0.21.0
# astropy==7.1.0
# astropy-iers-data==0.2025.6.23.0.39.50
# asttokens==3.0.0
# astunparse==1.6.3
# atpublic==5.1
# attrs==25.3.0
# audioread==3.0.1
# autograd==1.8.0
# babel==2.17.0
# backcall==0.2.0
# backports.tarfile==1.2.0
# bayesian-optimization==3.0.0
# beartype==0.21.0
# beautifulsoup4==4.13.4
# betterproto==2.0.0b6
# bigframes==2.8.0
# ...
